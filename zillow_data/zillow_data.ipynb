# %%
import pandas as pd

# %%
one_bed_url='1_bed.csv'
two_bed_url='2_bed.csv'

one_bed_df=pd.read_csv(one_bed_url)
one_bed_df.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank  2010-02  2010-03  2010-04  2010-05  ...  \
# 0                 37         1      NaN   1375.0   1450.0   1500.0  ...
# 1                 31         2      NaN   1105.0   1140.0   1100.0  ...
# 2                201         3      NaN      NaN      NaN      NaN  ...
# 3                 13         4      NaN      NaN      NaN      NaN  ...
# 4                 73         5      NaN      NaN      NaN      NaN  ...
#
# ...

# %%
two_bed_df=pd.read_csv(two_bed_url)
two_bed_df.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank  2010-01  2010-02  2010-03  2010-04  ...  \
# 0                 37         1      NaN   1900.0   1900.0   1950.0  ...
# 1                 31         2      NaN      NaN   1400.0   1485.0  ...
# 2                201         3      NaN      NaN      NaN      NaN  ...
# 3                 13         4      NaN      NaN      NaN      NaN  ...
# 4                 73         5      NaN      NaN      NaN      NaN  ...
#
# ...

# %%
#1-bed and 2-bed merge
one_two_bed_merge = pd.merge(one_bed_df, two_bed_df, on="RegionName", how="outer")
one_two_bed_merge
# Out:
#                  RegionName State_x                                Metro_x  \
# 0        Los Angeles County      CA         Los Angeles-Long Beach-Anaheim
# 1               Cook County      IL               Chicago-Naperville-Elgin
# 2             Harris County      TX       Houston-The Woodlands-Sugar Land
# 3           Maricopa County      AZ                Phoenix-Mesa-Scottsdale
# 4          San Diego County      CA                     San Diego-Carlsbad
# 5             Orange County      CA         Los Angeles-Long Beach-Anaheim
# 6             Orange County      CA         Los Angeles-Long Beach-Anaheim
# 7             Orange County      CA         Los Angeles-Long Beach-Anaheim
# 8             Orange County      FL              Orlando-Kissimmee-Sanford
# 9             Orange County      FL              Orlando-Kissimmee-Sanford
# 10            Orange County      FL              Orlando-Kissimmee-Sanford
# ...
